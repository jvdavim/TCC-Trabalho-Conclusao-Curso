# %%
test_size = 7
datasets = [{
    'name': 'casos_confirmados',
    'path': 'data/covid/casos_confirmados.csv'
}, {
    'name': 'sinteticos',
    'path': 'data/sinteticos/sinteticos.csv'
}, {
    'name': 'temperaturas',
    'path': 'data/temperatura_minima_diaria/temperaturas.csv'
}]
metrics = ['rmse', 'mape', 'mae', 'mpe']

# %%
for dataset in datasets:
    for metric in metrics:
        cmd = f"python -m memory_profiler rew_memory.py --dataset-path {dataset['path']} --dataset-name {dataset['name']} --metric {metric}"
        print('-'*120)
        print(f"Dataset: {dataset['name']} | Metric: {metric}")
        # !{cmd}
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: rmse
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  203.090 MiB  203.090 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.602 MiB    0.512 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.602 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mape
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.547 MiB  202.547 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  202.547 MiB    0.000 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  202.547 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mae
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.316 MiB  202.316 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  202.902 MiB    0.586 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  202.902 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mpe
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.840 MiB  202.840 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.484 MiB    0.645 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.484 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: rmse
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.746 MiB  202.746 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.344 MiB    0.598 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.344 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mape
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.770 MiB  202.770 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.340 MiB    0.570 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.340 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mae
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.566 MiB  202.566 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.465 MiB    0.898 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.465 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mpe
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.781 MiB  202.781 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.344 MiB    0.562 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.344 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: rmse
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.438 MiB  202.438 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.477 MiB    1.039 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.477 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mape
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.801 MiB  202.801 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.723 MiB    0.922 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.723 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mae
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.816 MiB  202.816 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.703 MiB    0.887 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.703 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mpe
# Filename: rew_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     17  202.984 MiB  202.984 MiB           1   @profile
#     18                                         def profile_memory(ts, thermometer, addr, order, mean, test_size) -> None:
#     19  203.793 MiB    0.809 MiB           1       model = RegressionWisardEstimator(ts, thermometer, addr, order=order, mean=mean).fit()
#     20  203.793 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)

# %%
for dataset in datasets:
    for metric in metrics:
        cmd = f"python -m memory_profiler arima_memory.py --dataset-path {dataset['path']} --dataset-name {dataset['name']} --metric {metric}"
        print('-'*120)
        print(f"Dataset: {dataset['name']} | Metric: {metric}")
        # !{cmd}
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: rmse
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.293 MiB  121.293 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  130.379 MiB    9.086 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  130.379 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mape
# /home/jvdavim/repositories/TCC-Trabalho-Conclusao-Curso/.venv/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.215 MiB  121.215 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  132.598 MiB   11.383 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  132.598 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mae
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.254 MiB  121.254 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  130.070 MiB    8.816 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  130.070 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mpe
# /home/jvdavim/repositories/TCC-Trabalho-Conclusao-Curso/.venv/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.609 MiB  121.609 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  135.344 MiB   13.734 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  135.344 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: rmse
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.113 MiB  121.113 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  124.219 MiB    3.105 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  125.344 MiB    1.125 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mape
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.027 MiB  121.027 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  124.105 MiB    3.078 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  125.246 MiB    1.141 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mae
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.242 MiB  121.242 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  124.602 MiB    3.359 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  125.645 MiB    1.043 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mpe
# /home/jvdavim/repositories/TCC-Trabalho-Conclusao-Curso/.venv/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.355 MiB  121.355 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  127.812 MiB    6.457 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  128.809 MiB    0.996 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: rmse
# /home/jvdavim/repositories/TCC-Trabalho-Conclusao-Curso/.venv/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  122.125 MiB  122.125 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  165.746 MiB   43.621 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  165.746 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mape
# /home/jvdavim/repositories/TCC-Trabalho-Conclusao-Curso/.venv/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.508 MiB  121.508 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  165.207 MiB   43.699 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  165.207 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mae
# /home/jvdavim/repositories/TCC-Trabalho-Conclusao-Curso/.venv/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  121.535 MiB  121.535 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  165.570 MiB   44.035 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  165.570 MiB    0.000 MiB           1       _ = model.forecast(steps=test_size)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mpe
# Filename: arima_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     15  122.055 MiB  122.055 MiB           1   @profile
#     16                                         def profile_memory(ts, order, test_size) -> None:
#     17  172.859 MiB   50.805 MiB           1       model = ARIMA(ts, order=order, enforce_stationarity=False, enforce_invertibility=False).fit()
#     18  173.227 MiB    0.367 MiB           1       _ = model.forecast(steps=test_size)

# %%
for dataset in datasets:
    for metric in metrics:
        cmd = f"python -m memory_profiler prophet_memory.py --dataset-path {dataset['path']} --dataset-name {dataset['name']} --metric {metric}"
        print('-'*120)
        print(f"Dataset: {dataset['name']} | Metric: {metric}")
        # !{cmd}
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: rmse
# Initial log joint probability = -212.946
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       44         438.8   5.43067e-09       3888.14      0.2309      0.5476       76
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.508 MiB  105.508 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  196.184 MiB   90.676 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  196.184 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  196.184 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  196.184 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  208.508 MiB   12.324 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mape
# Initial log joint probability = -212.946
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       45       445.108   9.17392e-09       3873.41      0.2465      0.2465       70
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.680 MiB  105.680 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  196.332 MiB   90.652 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  196.332 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  196.332 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  196.332 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  208.520 MiB   12.188 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mae
# Initial log joint probability = -212.946
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       44         438.8   5.43067e-09       3888.14      0.2309      0.5476       76
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.582 MiB  105.582 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  196.203 MiB   90.621 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  196.203 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  196.203 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  196.203 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  208.523 MiB   12.320 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: casos_confirmados | Metric: mpe
# Initial log joint probability = -212.946
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       45       445.108   9.17392e-09       3873.41      0.2465      0.2465       70
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.688 MiB  105.688 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  196.305 MiB   90.617 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  196.305 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  196.305 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  196.305 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  208.551 MiB   12.246 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: rmse
# Initial log joint probability = -9.67247
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       81       355.391    0.00353399       70.3303   7.838e-05       0.001      128  LS failed, Hessian reset
#       99       355.734    0.00822643       28.5648       7.456      0.7456      150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      168        356.18   0.000558683       27.8226   1.802e-05       0.001      290  LS failed, Hessian reset
#      199       356.265   0.000369641       19.1588      0.8989      0.8989      333
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       356.413    0.00117417       31.9459           1           1      469
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      324        356.45   0.000171049       39.4537   4.514e-06       0.001      578  LS failed, Hessian reset
#      399       356.591   0.000231486       29.3506      0.7032      0.7032      672
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       356.639   6.77803e-05       38.0727           1           1      821
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      595       356.661   4.88379e-05       24.3465   3.346e-06       0.001     1000  LS failed, Hessian reset
#      599       356.663   1.99922e-05       31.8965      0.6213      0.6213     1004
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      653       356.665   1.17595e-05       34.3883   3.365e-07       0.001     1133  LS failed, Hessian reset
#      687       356.666   4.00391e-08       20.0313     0.04097           1     1180
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.797 MiB  105.797 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  195.516 MiB   89.719 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  196.055 MiB    0.539 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  196.055 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  196.055 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  203.793 MiB    7.738 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mape
# Initial log joint probability = -9.67247
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       81       355.391    0.00353399       70.3303   7.838e-05       0.001      128  LS failed, Hessian reset
#       99       355.734    0.00822643       28.5648       7.456      0.7456      150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      168        356.18   0.000558683       27.8226   1.802e-05       0.001      290  LS failed, Hessian reset
#      199       356.265   0.000369641       19.1588      0.8989      0.8989      333
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       356.413    0.00117417       31.9459           1           1      469
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      324        356.45   0.000171049       39.4537   4.514e-06       0.001      578  LS failed, Hessian reset
#      399       356.591   0.000231486       29.3506      0.7032      0.7032      672
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       356.639   6.77803e-05       38.0727           1           1      821
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      595       356.661   4.88379e-05       24.3465   3.346e-06       0.001     1000  LS failed, Hessian reset
#      599       356.663   1.99922e-05       31.8965      0.6213      0.6213     1004
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      653       356.665   1.17595e-05       34.3883   3.365e-07       0.001     1133  LS failed, Hessian reset
#      687       356.666   4.00391e-08       20.0313     0.04097           1     1180
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.449 MiB  105.449 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  194.652 MiB   89.203 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  194.652 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  194.652 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  194.652 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  202.832 MiB    8.180 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mae
# Initial log joint probability = -9.67247
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       81       355.391    0.00353399       70.3303   7.838e-05       0.001      128  LS failed, Hessian reset
#       99       355.734    0.00822643       28.5648       7.456      0.7456      150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      168        356.18   0.000558683       27.8226   1.802e-05       0.001      290  LS failed, Hessian reset
#      199       356.265   0.000369641       19.1588      0.8989      0.8989      333
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       356.413    0.00117417       31.9459           1           1      469
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      324        356.45   0.000171049       39.4537   4.514e-06       0.001      578  LS failed, Hessian reset
#      399       356.591   0.000231486       29.3506      0.7032      0.7032      672
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       356.639   6.77803e-05       38.0727           1           1      821
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      595       356.661   4.88379e-05       24.3465   3.346e-06       0.001     1000  LS failed, Hessian reset
#      599       356.663   1.99922e-05       31.8965      0.6213      0.6213     1004
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      653       356.665   1.17595e-05       34.3883   3.365e-07       0.001     1133  LS failed, Hessian reset
#      687       356.666   4.00391e-08       20.0313     0.04097           1     1180
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.680 MiB  105.680 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  195.105 MiB   89.426 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  195.770 MiB    0.664 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  195.770 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  195.770 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  205.285 MiB    9.516 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: sinteticos | Metric: mpe
# Initial log joint probability = -9.67247
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       81       355.391    0.00353399       70.3303   7.838e-05       0.001      128  LS failed, Hessian reset
#       99       355.734    0.00822643       28.5648       7.456      0.7456      150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      168        356.18   0.000558683       27.8226   1.802e-05       0.001      290  LS failed, Hessian reset
#      199       356.265   0.000369641       19.1588      0.8989      0.8989      333
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       356.413    0.00117417       31.9459           1           1      469
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      324        356.45   0.000171049       39.4537   4.514e-06       0.001      578  LS failed, Hessian reset
#      399       356.591   0.000231486       29.3506      0.7032      0.7032      672
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       356.639   6.77803e-05       38.0727           1           1      821
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      595       356.661   4.88379e-05       24.3465   3.346e-06       0.001     1000  LS failed, Hessian reset
#      599       356.663   1.99922e-05       31.8965      0.6213      0.6213     1004
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      653       356.665   1.17595e-05       34.3883   3.365e-07       0.001     1133  LS failed, Hessian reset
#      687       356.666   4.00391e-08       20.0313     0.04097           1     1180
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.324 MiB  105.324 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  194.602 MiB   89.277 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  194.602 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  195.113 MiB    0.512 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  195.113 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  202.789 MiB    7.676 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: rmse
# Initial log joint probability = -106.057
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       65        7070.5    0.00131558       3694.56   3.459e-07       0.001      115  LS failed, Hessian reset
#       99       7073.29   1.53802e-06       3891.09           1           1      160
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      103       7073.33   1.00265e-05       3884.89    2.69e-09       0.001      209  LS failed, Hessian reset
#      134       7073.37   4.35125e-07       3888.01   1.131e-10       0.001      296  LS failed, Hessian reset
#      143       7073.37   7.20566e-09       3755.95      0.4243           1      310
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.094 MiB  105.094 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  206.793 MiB  101.699 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  206.793 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  206.793 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  206.793 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  210.801 MiB    4.008 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mape
# Initial log joint probability = -106.057
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       7052.81   6.05657e-07       3843.41      0.9058      0.9058      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      110       7063.17    0.00173788       4312.94    4.26e-07       0.001      189  LS failed, Hessian reset
#      140        7070.9   0.000250149       4108.03   6.846e-08       0.001      278  LS failed, Hessian reset
#      164       7071.54   8.51592e-06       3919.61   2.318e-09       0.001      352  LS failed, Hessian reset
#      191       7071.58   7.43517e-09       3847.88      0.1883      0.1883      395
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.305 MiB  105.305 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  207.379 MiB  102.074 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  207.379 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  207.379 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  207.379 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  211.652 MiB    4.273 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mae
# Initial log joint probability = -106.057
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       7052.81   6.05657e-07       3843.41      0.9058      0.9058      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      110       7063.17    0.00173788       4312.94    4.26e-07       0.001      189  LS failed, Hessian reset
#      140        7070.9   0.000250149       4108.03   6.846e-08       0.001      278  LS failed, Hessian reset
#      164       7071.54   8.51592e-06       3919.61   2.318e-09       0.001      352  LS failed, Hessian reset
#      191       7071.58   7.43517e-09       3847.88      0.1883      0.1883      395
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.309 MiB  105.309 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  207.582 MiB  102.273 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  207.582 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  207.582 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  207.582 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  211.797 MiB    4.215 MiB           1       _ = m.predict(future)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Dataset: temperaturas | Metric: mpe
# Initial log joint probability = -106.057
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       98       7064.98   6.72573e-06          3913   1.726e-09       0.001      176  LS failed, Hessian reset
#       99       7064.98   1.94688e-06       3859.78      0.2378           1      178
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      120          7065    6.3906e-07        3875.9    1.62e-10       0.001      246  LS failed, Hessian reset
#      135          7065   8.94041e-09       3894.58      0.2833      0.2833      265
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Filename: prophet_memory.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#     16  105.141 MiB  105.141 MiB           1   @profile
#     17                                         def profile_memory(ts, parameters, test_size) -> None:
#     18  207.066 MiB  101.926 MiB           1       m = Prophet(**parameters).fit(ts)
#     19  207.066 MiB    0.000 MiB           1       future = m.make_future_dataframe(periods=test_size)
#     20  207.066 MiB    0.000 MiB           1       future['floor'] = ts.loc[:, 'floor'].iloc[0]
#     21  207.066 MiB    0.000 MiB           1       future['cap'] = ts.loc[:, 'cap'].iloc[0]
#     22  211.270 MiB    4.203 MiB           1       _ = m.predict(future)
